# %%
import csv  # For handling CSV files
import nltk  # Natural Language Toolkit for text processing
from nltk.tokenize import word_tokenize  # Tokenizer
from nltk.corpus import stopwords  # For stopwords
from nltk.stem import PorterStemmer  # Stemmer

# Define the path to the CSV file containing the dataset
csv_file_path = '/content/Training-dataset.csv'

# Initialize lists to store data from the CSV file
ids = []
titles = []
plots = []

# Open and read the CSV file
with open(csv_file_path, 'r', encoding='utf-8') as file:
    csv_reader = csv.DictReader(file)
    # Loop through each row in the CSV file
    for row in csv_reader:
        # Append the relevant data to the respective lists
        ids.append(row['ID'])
        titles.append(row['title'])
        plots.append(row['plot_synopsis'])

# Import regular expression library
import re

def clean_plot(plot):
    # Remove non-alphabetic characters from the plot synopsis
    plot = re.sub(r'[^a-zA-Z ]', '', plot)
    return plot

# Download necessary NLTK packages
nltk.download('punkt')  # For tokenization
nltk.download('stopwords')  # For stopwords

from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')  # Download WordNet database for lemmatization

# Initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to lemmatize a list of tokens
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# Load English stopwords
stop_words = stopwords.words('english')

def process_plot(plot):
    cleaned_plot = clean_plot(plot)  # Clean the plot
    tokenized_plot = word_tokenize(cleaned_plot.lower())  # Tokenize the cleaned plot
    lemmatized_plot = lemmatize_tokens(tokenized_plot)  # Lemmatize the tokens
    # Remove stopwords from the plot
    filtered_plot = [word for word in lemmatized_plot if word not in stop_words]
    return filtered_plot

# Process each plot synopsis
processed_plots_tokens = [process_plot(plot) for plot in plots]

# Join the list of words back into strings
training_plots = [' '.join(plot_tokens) for plot_tokens in processed_plots_tokens]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Method a) sparse representation (BoW with PPMI)

# Import CountVectorizer for feature extraction
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# Flatten the list of tokens
tokens = [token for plot_tokens in processed_plots_tokens for token in plot_tokens]

# Get unique tokens
unique_tokens = set(tokens)
unique_tokens = list(unique_tokens)
print(len(unique_tokens))

# Initialize CountVectorizer with the unique tokens as vocabulary
vectorizer = CountVectorizer(vocabulary=unique_tokens)

# Fit and transform the data
dtm = vectorizer.fit_transform(training_plots)

# Import necessary modules for PPMI calculation
from sklearn.metrics import pairwise_distances
from scipy.sparse import csr_matrix

# Convert the term-document matrix to a sparse CSR matrix
dtm = csr_matrix(dtm)

def calculate_ppmi(dtm):
    # Calculate marginal probabilities
    sum_words = np.array(dtm.sum(axis=1)).flatten()
    sum_contexts = np.array(dtm.sum(axis=0)).flatten()
    total_sum = sum_words.sum()

    # Calculate Pointwise Mutual Information (PMI)
    pmi_matrix = np.log(((dtm * total_sum) / np.outer(sum_words, sum_contexts)).toarray() + 1e-8)

    # Calculate Positive PMI (PPMI) by removing negative values
    ppmi_matrix = np.maximum(pmi_matrix, 0)

    return ppmi_matrix

# Calculate PPMI matrix
ppmi_matrix = calculate_ppmi(dtm)

# Create a mapping of words to their indices
word_to_index = {word: index for index, word in enumerate(unique_tokens)}

# Function to compute cosine similarity between two vectors
def cosine_similarity(vec1, vec2):
    similarity = 0

    # Check if both words are in the vocabulary
    if word1 in word_to_index and word2 in word_to_index:
      # Get indices of the words
      word1_index = word_to_index[word1]
      word2_index = word_to_index[word2]

      # Extract vectors
      vec1 = ppmi_matrix[:, word1_index].flatten()
      vec2 = ppmi_matrix[:, word2_index].flatten()

      # Compute cosine similarity
      dot_product = np.dot(vec1, vec2)
      norm_vec1 = np.linalg.norm(vec1)
      norm_vec2 = np.linalg.norm(vec2)
      similarity = dot_product / (norm_vec1 * norm_vec2)

    return similarity
# Out:
# 150780
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_base.py:659: RuntimeWarning: divide by zero encountered in divide
#   recip = np.true_divide(1., other)

# %%
# Method b) dense static representation (word2vec)

# Import the Word2Vec model from gensim for word embeddings
from gensim.models import Word2Vec

# Initialize the Word2Vec model with specified parameters
model = Word2Vec(vector_size=150, window=5, min_count=1, workers=4, sg=0)

# Build the vocabulary from the processed plot tokens for the Word2Vec model
model.build_vocab(processed_plots_tokens)

# Train the Word2Vec model using the processed plot tokens
model.train(processed_plots_tokens, total_examples=model.corpus_count, epochs=10)

# Function to calculate similarity between two words using the Word2Vec model
def get_similarity_word2vec(word1, word2):
    similarity = 0
    # Check if both words are in the model's vocabulary
    if word1 in model.wv.key_to_index and word2 in model.wv.key_to_index:
        # Calculate and return the cosine similarity between the two words
        similarity = model.wv.similarity(word1, word2)
    return similarity

# %%
import csv

document_similarities = []

with open('/content/Task-1-validation-dataset.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        index, word1, word2, similarity = row
        document_similarities.append((index, word1, word2, float(similarity)))

similarities = []

for index, word1, word2, similarity in document_similarities:
    similarity_score = cosine_similarity(word1, word2)
    similarities.append((index, similarity_score))

filename = "10749545-Task1-method-a-validation.csv"
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)

    for index, similarity in similarities:

        row = [index] + [similarity]
        writer.writerow(row)

# %%
# %run '/content/task1_eval_script_student_version(1).py' /content/10749545-Task1-method-a-validation.csv /content/Task-1-validation-dataset.csv
# Out:
# The following simalarity scores may need checking:
# (achieve,accomplish) similarity score: 0.013896852042201353, gold ranking: 8.57
# (achieve,try) similarity score: 0.03784001613817241, gold ranking: 4.42
# ----------------------------
# (acquire,get) similarity score: 0.01993848292200949, gold ranking: 8.82
# (acquire,obtain) similarity score: 0.07760885941813246, gold ranking: 8.57
# ----------------------------
# (acquire,get) similarity score: 0.01993848292200949, gold ranking: 8.82
# (acquire,find) similarity score: 0.04968694998435809, gold ranking: 6.38
# ----------------------------
# (apple,sauce) similarity score: 0.0, gold ranking: 1.43
# (apple,sunshine) similarity score: 0.0, gold ranking: 0.58
# ----------------------------
# (arm,shoulder) similarity score: 0.11749415179521437, gold ranking: 4.85
# (arm,body) similarity score: 0.18248182200364838, gold ranking: 4.05
# ----------------------------
# (arm,shoulder) similarity score: 0.11749415179521437, gold ranking: 4.85
# (arm,neck) similarity score: 0.17478245163434974, gold ranking: 1.58
# ----------------------------
# (arm,vein) similarity score: 0.029421773450668747, gold ranking: 3.65
# (arm,knee) similarity score: 0.05518895904618704, gold ranking: 2.75
# ----------------------------
# (arm,vein) similarity score: 0.029421773450668747, gold ranking: 3.65
# (arm,neck) similarity score: 0.17478245163434974, gold ranking: 1.58
# ----------------------------
# (arm,knee) similarity score: 0.05518895904618704, gold ranking: 2.75
# (arm,neck) similarity score: 0.17478245163434974, gold ranking: 1.58
# ----------------------------
# (arm,bone) similarity score: 0.07784705952842166, gold ranking: 3.83
# (arm,neck) similarity score: 0.17478245163434974, gold ranking: 1.58
# ----------------------------
# (bath,trick) similarity score: 0.05162643843060816, gold ranking: 0.58
# (bath,wife) similarity score: 0.06395840592501581, gold ranking: 0.48
# ----------------------------
# (bed,bedroom) similarity score: 0.29464889174672765, gold ranking: 3.4
# (bed,crib) similarity score: 0.034089080321632936, gold ranking: 7.3
# ----------------------------
# (bed,bedroom) similarity score: 0.29464889174672765, gold ranking: 3.4
# (bed,chair) similarity score: 0.1371221234584423, gold ranking: 3.5
# ----------------------------
# (bed,blanket) similarity score: 0.10442105342285356, gold ranking: 3.02
# (bed,crib) similarity score: 0.034089080321632936, gold ranking: 7.3
# ----------------------------
# (bed,blanket) similarity score: 0.10442105342285356, gold ranking: 3.02
# (bed,hospital) similarity score: 0.20125967506099182, gold ranking: 0.92
# ----------------------------
# (bed,crib) similarity score: 0.034089080321632936, gold ranking: 7.3
# (bed,hospital) similarity score: 0.20125967506099182, gold ranking: 0.92
# ----------------------------
# (bed,crib) similarity score: 0.034089080321632936, gold ranking: 7.3
# (bed,chair) similarity score: 0.1371221234584423, gold ranking: 3.5
# ----------------------------
# (bed,hospital) similarity score: 0.20125967506099182, gold ranking: 0.92
# (bed,chair) similarity score: 0.1371221234584423, gold ranking: 3.5
# ----------------------------
# (belief,opinion) similarity score: 0.07124164261995197, gold ranking: 7.7
# (belief,flower) similarity score: 0.09028921607687676, gold ranking: 0.4
# ----------------------------
# (belief,concept) similarity score: 0.05252535881973834, gold ranking: 5.08
# (belief,impression) similarity score: 0.032627840101567065, gold ranking: 5.95
# ----------------------------
# (belief,concept) similarity score: 0.05252535881973834, gold ranking: 5.08
# (belief,flower) similarity score: 0.09028921607687676, gold ranking: 0.4
# ----------------------------
# (belief,impression) similarity score: 0.032627840101567065, gold ranking: 5.95
# (belief,flower) similarity score: 0.09028921607687676, gold ranking: 0.4
# ----------------------------
# (bird,hawk) similarity score: 0.033676473083144046, gold ranking: 7.85
# (bird,turkey) similarity score: 0.03518927293293875, gold ranking: 6.58
# ----------------------------
# (bird,hawk) similarity score: 0.033676473083144046, gold ranking: 7.85
# (bird,hen) similarity score: 0.04913868174760499, gold ranking: 7.03
# ----------------------------
# (bird,turkey) similarity score: 0.03518927293293875, gold ranking: 6.58
# (bird,cock) similarity score: 0.017008119410570652, gold ranking: 7.1
# ----------------------------
# (bird,hen) similarity score: 0.04913868174760499, gold ranking: 7.03
# (bird,cock) similarity score: 0.017008119410570652, gold ranking: 7.1
# ----------------------------
# (bone,jaw) similarity score: 0.019299939604766198, gold ranking: 4.17
# (bone,ankle) similarity score: 0.02600004126492148, gold ranking: 3.82
# ----------------------------
# (bone,jaw) similarity score: 0.019299939604766198, gold ranking: 4.17
# (bone,neck) similarity score: 0.05403065330515887, gold ranking: 2.53
# ----------------------------
# (bone,ankle) similarity score: 0.02600004126492148, gold ranking: 3.82
# (bone,neck) similarity score: 0.05403065330515887, gold ranking: 2.53
# ----------------------------
# (bone,knee) similarity score: 0.05450918177798398, gold ranking: 4.17
# (bone,teeth) similarity score: 0.04564877724161786, gold ranking: 4.17
# ----------------------------
# (bone,neck) similarity score: 0.05403065330515887, gold ranking: 2.53
# (bone,teeth) similarity score: 0.04564877724161786, gold ranking: 4.17
# ----------------------------
# (bone,neck) similarity score: 0.05403065330515887, gold ranking: 2.53
# (bone,elbow) similarity score: 0.016257875660259255, gold ranking: 3.78
# ----------------------------
# (book,literature) similarity score: 0.10495868478912816, gold ranking: 7.53
# (book,story) similarity score: 0.19212713113192056, gold ranking: 5.63
# ----------------------------
# (book,bible) similarity score: 0.0791549424675235, gold ranking: 5.0
# (book,article) similarity score: 0.07368681319579541, gold ranking: 5.43
# ----------------------------
# (book,information) similarity score: 0.09586341404094802, gold ranking: 5.0
# (book,article) similarity score: 0.07368681319579541, gold ranking: 5.43
# ----------------------------
# (book,essay) similarity score: 0.058787423487309705, gold ranking: 4.72
# (book,theme) similarity score: 0.06987612389890284, gold ranking: 2.58
# ----------------------------
# (cat,lion) similarity score: 0.05216668292204509, gold ranking: 6.75
# (cat,pet) similarity score: 0.10967911995756902, gold ranking: 5.95
# ----------------------------
# (clothes,drawer) similarity score: 0.08596698369161065, gold ranking: 3.02
# (clothes,fabric) similarity score: 0.017305969089189036, gold ranking: 5.87
# ----------------------------
# (clothes,drawer) similarity score: 0.08596698369161065, gold ranking: 3.02
# (clothes,jacket) similarity score: 0.07157155277461706, gold ranking: 5.15
# ----------------------------
# (clothes,fabric) similarity score: 0.017305969089189036, gold ranking: 5.87
# (clothes,button) similarity score: 0.04239179476092836, gold ranking: 2.3
# ----------------------------
# (clothes,fabric) similarity score: 0.017305969089189036, gold ranking: 5.87
# (clothes,coat) similarity score: 0.10087181555359713, gold ranking: 5.35
# ----------------------------
# (clothes,fabric) similarity score: 0.017305969089189036, gold ranking: 5.87
# (clothes,jacket) similarity score: 0.07157155277461706, gold ranking: 5.15
# ----------------------------
# (cup,cone) similarity score: 0.03320833634576271, gold ranking: 3.17
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# ----------------------------
# (cup,cone) similarity score: 0.03320833634576271, gold ranking: 3.17
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# ----------------------------
# (cup,cone) similarity score: 0.03320833634576271, gold ranking: 3.17
# (cup,article) similarity score: 0.055577876422443884, gold ranking: 2.4
# ----------------------------
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# ----------------------------
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# (cup,artifact) similarity score: 0.025172858365826885, gold ranking: 2.92
# ----------------------------
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# (cup,object) similarity score: 0.04250218730282932, gold ranking: 3.69
# ----------------------------
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# (cup,food) similarity score: 0.055510926493634594, gold ranking: 5.0
# ----------------------------
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# (cup,article) similarity score: 0.055577876422443884, gold ranking: 2.4
# ----------------------------
# (cup,jar) similarity score: 0.02166616776173773, gold ranking: 5.13
# (cup,substance) similarity score: 0.02228375356555036, gold ranking: 1.92
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,artifact) similarity score: 0.025172858365826885, gold ranking: 2.92
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,object) similarity score: 0.04250218730282932, gold ranking: 3.69
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,entity) similarity score: 0.0, gold ranking: 2.15
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,food) similarity score: 0.055510926493634594, gold ranking: 5.0
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,article) similarity score: 0.055577876422443884, gold ranking: 2.4
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,substance) similarity score: 0.02228375356555036, gold ranking: 1.92
# ----------------------------
# (cup,artifact) similarity score: 0.025172858365826885, gold ranking: 2.92
# (cup,article) similarity score: 0.055577876422443884, gold ranking: 2.4
# ----------------------------
# (cup,object) similarity score: 0.04250218730282932, gold ranking: 3.69
# (cup,article) similarity score: 0.055577876422443884, gold ranking: 2.4
# ----------------------------
# (cup,entity) similarity score: 0.0, gold ranking: 2.15
# (cup,substance) similarity score: 0.02228375356555036, gold ranking: 1.92
# ----------------------------
# (cup,food) similarity score: 0.055510926493634594, gold ranking: 5.0
# (cup,article) similarity score: 0.055577876422443884, gold ranking: 2.4
# ----------------------------
# (drink,eat) similarity score: 0.12756114825311232, gold ranking: 6.87
# (drink,car) similarity score: 0.16471000281012638, gold ranking: 3.04
# ----------------------------
# (father,parent) similarity score: 0.26068454761158644, gold ranking: 7.07
# (father,daughter) similarity score: 0.31301600688551817, gold ranking: 2.62
# ----------------------------
# (father,parent) similarity score: 0.26068454761158644, gold ranking: 7.07
# (father,brother) similarity score: 0.27248582336651644, gold ranking: 4.2
# ----------------------------
# (father,daughter) similarity score: 0.31301600688551817, gold ranking: 2.62
# (father,brother) similarity score: 0.27248582336651644, gold ranking: 4.2
# ----------------------------
# (father,daughter) similarity score: 0.31301600688551817, gold ranking: 2.62
# (father,god) similarity score: 0.11222903455321805, gold ranking: 3.57
# ----------------------------
# (flower,violet) similarity score: 0.025463301112054457, gold ranking: 6.95
# (flower,bulb) similarity score: 0.032079513935083126, gold ranking: 4.48
# ----------------------------
# (guy,stud) similarity score: 0.014795720808003848, gold ranking: 5.83
# (guy,partner) similarity score: 0.06503616637713693, gold ranking: 3.57
# ----------------------------
# (guy,stud) similarity score: 0.014795720808003848, gold ranking: 5.83
# (guy,girl) similarity score: 0.1580950037862046, gold ranking: 3.33
# ----------------------------
# (guy,partner) similarity score: 0.06503616637713693, gold ranking: 3.57
# (guy,girl) similarity score: 0.1580950037862046, gold ranking: 3.33
# ----------------------------
# (join,add) similarity score: 0.06886349657115592, gold ranking: 8.1
# (join,marry) similarity score: 0.13391570957008322, gold ranking: 5.35
# ----------------------------
# (king,princess) similarity score: 0.2666673381045385, gold ranking: 3.27
# (king,rook) similarity score: 0.0, gold ranking: 5.92
# ----------------------------
# (king,rook) similarity score: 0.0, gold ranking: 5.92
# (king,cabbage) similarity score: 0.0, gold ranking: 0.23
# ----------------------------
# (lose,fail) similarity score: 0.04883895216831734, gold ranking: 7.33
# (lose,keep) similarity score: 0.10604854415640505, gold ranking: 1.05
# ----------------------------
# (lose,fail) similarity score: 0.04883895216831734, gold ranking: 7.33
# (lose,get) similarity score: 0.13509051516948242, gold ranking: 0.77
# ----------------------------
# (lose,keep) similarity score: 0.10604854415640505, gold ranking: 1.05
# (lose,get) similarity score: 0.13509051516948242, gold ranking: 0.77
# ----------------------------
# (man,uncle) similarity score: 0.11843418465119386, gold ranking: 3.92
# (man,warrior) similarity score: 0.06293438527439095, gold ranking: 4.72
# ----------------------------
# (man,uncle) similarity score: 0.11843418465119386, gold ranking: 3.92
# (man,governor) similarity score: 0.059830915100034805, gold ranking: 5.25
# ----------------------------
# (man,father) similarity score: 0.2278638995185475, gold ranking: 4.83
# (man,husband) similarity score: 0.20600188402293648, gold ranking: 5.32
# ----------------------------
# (man,father) similarity score: 0.2278638995185475, gold ranking: 4.83
# (man,governor) similarity score: 0.059830915100034805, gold ranking: 5.25
# ----------------------------
# (man,child) similarity score: 0.20994578655246787, gold ranking: 4.13
# (man,husband) similarity score: 0.20600188402293648, gold ranking: 5.32
# ----------------------------
# (man,child) similarity score: 0.20994578655246787, gold ranking: 4.13
# (man,warrior) similarity score: 0.06293438527439095, gold ranking: 4.72
# ----------------------------
# (man,child) similarity score: 0.20994578655246787, gold ranking: 4.13
# (man,governor) similarity score: 0.059830915100034805, gold ranking: 5.25
# ----------------------------
# (man,victor) similarity score: 0.05789954556142656, gold ranking: 1.9
# (man,sentry) similarity score: 0.019180263511146132, gold ranking: 3.25
# ----------------------------
# (man,warrior) similarity score: 0.06293438527439095, gold ranking: 4.72
# (man,governor) similarity score: 0.059830915100034805, gold ranking: 5.25
# ----------------------------
# (meat,bacon) similarity score: 0.019672064898143733, gold ranking: 5.8
# (meat,bread) similarity score: 0.044197614525968404, gold ranking: 1.67
# ----------------------------
# (media,radio) similarity score: 0.0, gold ranking: 7.42
# (media,trading) similarity score: 0.0, gold ranking: 3.88
# ----------------------------
# (money,salary) similarity score: 0.05189486909684896, gold ranking: 7.88
# (money,diamond) similarity score: 0.0758525668468108, gold ranking: 3.42
# ----------------------------
# (precedent,antecedent) similarity score: 0.0, gold ranking: 6.04
# (precedent,information) similarity score: 0.011843190492405026, gold ranking: 3.85
# ----------------------------
# (precedent,antecedent) similarity score: 0.0, gold ranking: 6.04
# (precedent,cognition) similarity score: 0.0, gold ranking: 2.81
# ----------------------------
# (precedent,antecedent) similarity score: 0.0, gold ranking: 6.04
# (precedent,group) similarity score: 0.003904393933396297, gold ranking: 1.77
# ----------------------------
# (precedent,cognition) similarity score: 0.0, gold ranking: 2.81
# (precedent,group) similarity score: 0.003904393933396297, gold ranking: 1.77
# ----------------------------
# (street,alley) similarity score: 0.17051359689282805, gold ranking: 5.48
# (street,car) similarity score: 0.2013124925944847, gold ranking: 2.38
# ----------------------------
# (street,alley) similarity score: 0.17051359689282805, gold ranking: 5.48
# (street,place) similarity score: 0.1583209051565776, gold ranking: 6.44
# ----------------------------
# (street,alley) similarity score: 0.17051359689282805, gold ranking: 5.48
# (street,avenue) similarity score: 0.06655667748420138, gold ranking: 8.88
# ----------------------------
# (street,car) similarity score: 0.2013124925944847, gold ranking: 2.38
# (street,place) similarity score: 0.1583209051565776, gold ranking: 6.44
# ----------------------------
# (street,car) similarity score: 0.2013124925944847, gold ranking: 2.38
# (street,avenue) similarity score: 0.06655667748420138, gold ranking: 8.88
# ----------------------------
# (street,place) similarity score: 0.1583209051565776, gold ranking: 6.44
# (street,avenue) similarity score: 0.06655667748420138, gold ranking: 8.88
# ----------------------------
# (take,obtain) similarity score: 0.08637685349472957, gold ranking: 7.1
# (take,receive) similarity score: 0.09885163923789073, gold ranking: 5.08
# ----------------------------
# (take,obtain) similarity score: 0.08637685349472957, gold ranking: 7.1
# (take,carry) similarity score: 0.1335761033499497, gold ranking: 5.23
# ----------------------------
# (take,obtain) similarity score: 0.08637685349472957, gold ranking: 7.1
# (take,deliver) similarity score: 0.09407636890878401, gold ranking: 4.37
# ----------------------------
# (take,obtain) similarity score: 0.08637685349472957, gold ranking: 7.1
# (take,leave) similarity score: 0.3014152857222698, gold ranking: 2.47
# ----------------------------
# (take,receive) similarity score: 0.09885163923789073, gold ranking: 5.08
# (take,leave) similarity score: 0.3014152857222698, gold ranking: 2.47
# ----------------------------
# (take,carry) similarity score: 0.1335761033499497, gold ranking: 5.23
# (take,leave) similarity score: 0.3014152857222698, gold ranking: 2.47
# ----------------------------
# (take,deliver) similarity score: 0.09407636890878401, gold ranking: 4.37
# (take,leave) similarity score: 0.3014152857222698, gold ranking: 2.47
# ----------------------------
# (tiger,feline) similarity score: 0.03763228943436632, gold ranking: 8.0
# (tiger,animal) similarity score: 0.10586410918007684, gold ranking: 7.0
# ----------------------------
# (tiger,feline) similarity score: 0.03763228943436632, gold ranking: 8.0
# (tiger,fauna) similarity score: 0.04527331839750666, gold ranking: 5.62
# ----------------------------
# (tiger,carnivore) similarity score: 0.0, gold ranking: 7.08
# (tiger,mammal) similarity score: 0.0, gold ranking: 6.85
# ----------------------------
# (tiger,carnivore) similarity score: 0.0, gold ranking: 7.08
# (tiger,animal) similarity score: 0.10586410918007684, gold ranking: 7.0
# ----------------------------
# (tiger,carnivore) similarity score: 0.0, gold ranking: 7.08
# (tiger,organism) similarity score: 0.0, gold ranking: 4.77
# ----------------------------
# (tiger,carnivore) similarity score: 0.0, gold ranking: 7.08
# (tiger,fauna) similarity score: 0.04527331839750666, gold ranking: 5.62
# ----------------------------
# (tiger,mammal) similarity score: 0.0, gold ranking: 6.85
# (tiger,organism) similarity score: 0.0, gold ranking: 4.77
# ----------------------------
# (tiger,mammal) similarity score: 0.0, gold ranking: 6.85
# (tiger,fauna) similarity score: 0.04527331839750666, gold ranking: 5.62
# ----------------------------
# (happy,cheerful) similarity score: 0.03181215551594497, gold ranking: 9.55
# (happy,young) similarity score: 0.14126247383409068, gold ranking: 2.0
# ----------------------------
# (car,highway) similarity score: 0.21151678064105633, gold ranking: 3.4
# (car,cab) similarity score: 0.09985968789780027, gold ranking: 7.42
# ----------------------------
# (bad,immoral) similarity score: 0.037231358446571196, gold ranking: 7.62
# (bad,great) similarity score: 0.10546179364858072, gold ranking: 0.35
# ----------------------------
# Accuracy: 0.5703703703703704

# %%
test_document_similarities = []

with open('/content/Task-1-test-dataset1.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        id, word1, word2 = row
        test_document_similarities.append((id, word1, word2))

test_similarities = []

for id, word1, word2 in test_document_similarities:
    similarity_score = cosine_similarity(word1, word2)
    test_similarities.append((id, similarity_score))

filename = "10749545-Task1-method-a.csv"
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)

    for id, similarity in test_similarities:
        row = [id] + [similarity]
        writer.writerow(row)

# %%
similarities_word2vec = []

for id, word1, word2, similarity in document_similarities:
    similarity_score = get_similarity_word2vec(word1, word2)
    similarities_word2vec.append((id, similarity_score))

filename = "10749545-Task1-method-b-validation.csv"
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    for index, similarity in similarities_word2vec:
        writer.writerow([index, similarity])

# %%
# %run '/content/task1_eval_script_student_version(1).py' /content/10749545-Task1-method-b-validation.csv /content/Task-1-validation-dataset.csv
# Out:
# The following simalarity scores may need checking:
# (absorb,learn) similarity score: 0.20379506, gold ranking: 5.48
# (absorb,withdraw) similarity score: 0.30235, gold ranking: 2.97
# ----------------------------
# (acquire,get) similarity score: 0.15894678, gold ranking: 8.82
# (acquire,obtain) similarity score: 0.7656169, gold ranking: 8.57
# ----------------------------
# (apple,sauce) similarity score: 0.4492793, gold ranking: 1.43
# (apple,lemon) similarity score: 0.33655682, gold ranking: 4.05
# ----------------------------
# (arm,shoulder) similarity score: 0.62591, gold ranking: 4.85
# (arm,neck) similarity score: 0.64391595, gold ranking: 1.58
# ----------------------------
# (arm,body) similarity score: 0.25507197, gold ranking: 4.05
# (arm,vein) similarity score: 0.37002456, gold ranking: 3.65
# ----------------------------
# (arm,body) similarity score: 0.25507197, gold ranking: 4.05
# (arm,knee) similarity score: 0.5776952, gold ranking: 2.75
# ----------------------------
# (arm,body) similarity score: 0.25507197, gold ranking: 4.05
# (arm,bone) similarity score: 0.465354, gold ranking: 3.83
# ----------------------------
# (arm,body) similarity score: 0.25507197, gold ranking: 4.05
# (arm,neck) similarity score: 0.64391595, gold ranking: 1.58
# ----------------------------
# (arm,vein) similarity score: 0.37002456, gold ranking: 3.65
# (arm,knee) similarity score: 0.5776952, gold ranking: 2.75
# ----------------------------
# (arm,vein) similarity score: 0.37002456, gold ranking: 3.65
# (arm,neck) similarity score: 0.64391595, gold ranking: 1.58
# ----------------------------
# (arm,knee) similarity score: 0.5776952, gold ranking: 2.75
# (arm,bone) similarity score: 0.465354, gold ranking: 3.83
# ----------------------------
# (arm,knee) similarity score: 0.5776952, gold ranking: 2.75
# (arm,neck) similarity score: 0.64391595, gold ranking: 1.58
# ----------------------------
# (arm,bone) similarity score: 0.465354, gold ranking: 3.83
# (arm,neck) similarity score: 0.64391595, gold ranking: 1.58
# ----------------------------
# (ball,cannon) similarity score: 0.37366748, gold ranking: 2.58
# (ball,basket) similarity score: 0.4236088, gold ranking: 1.67
# ----------------------------
# (bath,trick) similarity score: 0.1206519, gold ranking: 0.58
# (bath,balloon) similarity score: 0.4713665, gold ranking: 0.4
# ----------------------------
# (bath,wife) similarity score: 0.04798253, gold ranking: 0.48
# (bath,balloon) similarity score: 0.4713665, gold ranking: 0.4
# ----------------------------
# (bed,bedroom) similarity score: 0.66534585, gold ranking: 3.4
# (bed,crib) similarity score: 0.5889579, gold ranking: 7.3
# ----------------------------
# (bed,blanket) similarity score: 0.60612863, gold ranking: 3.02
# (bed,crib) similarity score: 0.5889579, gold ranking: 7.3
# ----------------------------
# (bed,crib) similarity score: 0.5889579, gold ranking: 7.3
# (bed,chair) similarity score: 0.6721996, gold ranking: 3.5
# ----------------------------
# (belief,concept) similarity score: 0.28998542, gold ranking: 5.08
# (belief,impression) similarity score: 0.2292862, gold ranking: 5.95
# ----------------------------
# (bird,turkey) similarity score: 0.27740943, gold ranking: 6.58
# (bird,cock) similarity score: 0.25042337, gold ranking: 7.1
# ----------------------------
# (bird,hen) similarity score: 0.28217566, gold ranking: 7.03
# (bird,cock) similarity score: 0.25042337, gold ranking: 7.1
# ----------------------------
# (bone,jaw) similarity score: 0.4675629, gold ranking: 4.17
# (bone,ankle) similarity score: 0.46878076, gold ranking: 3.82
# ----------------------------
# (bone,jaw) similarity score: 0.4675629, gold ranking: 4.17
# (bone,knee) similarity score: 0.43017542, gold ranking: 4.17
# ----------------------------
# (bone,jaw) similarity score: 0.4675629, gold ranking: 4.17
# (bone,neck) similarity score: 0.50893724, gold ranking: 2.53
# ----------------------------
# (bone,jaw) similarity score: 0.4675629, gold ranking: 4.17
# (bone,elbow) similarity score: 0.48093385, gold ranking: 3.78
# ----------------------------
# (bone,ankle) similarity score: 0.46878076, gold ranking: 3.82
# (bone,knee) similarity score: 0.43017542, gold ranking: 4.17
# ----------------------------
# (bone,ankle) similarity score: 0.46878076, gold ranking: 3.82
# (bone,neck) similarity score: 0.50893724, gold ranking: 2.53
# ----------------------------
# (bone,ankle) similarity score: 0.46878076, gold ranking: 3.82
# (bone,elbow) similarity score: 0.48093385, gold ranking: 3.78
# ----------------------------
# (bone,knee) similarity score: 0.43017542, gold ranking: 4.17
# (bone,neck) similarity score: 0.50893724, gold ranking: 2.53
# ----------------------------
# (bone,knee) similarity score: 0.43017542, gold ranking: 4.17
# (bone,elbow) similarity score: 0.48093385, gold ranking: 3.78
# ----------------------------
# (bone,neck) similarity score: 0.50893724, gold ranking: 2.53
# (bone,elbow) similarity score: 0.48093385, gold ranking: 3.78
# ----------------------------
# (book,literature) similarity score: 0.3822697, gold ranking: 7.53
# (book,story) similarity score: 0.44187, gold ranking: 5.63
# ----------------------------
# (book,literature) similarity score: 0.3822697, gold ranking: 7.53
# (book,bible) similarity score: 0.69143414, gold ranking: 5.0
# ----------------------------
# (book,literature) similarity score: 0.3822697, gold ranking: 7.53
# (book,topic) similarity score: 0.39124542, gold ranking: 2.07
# ----------------------------
# (book,literature) similarity score: 0.3822697, gold ranking: 7.53
# (book,essay) similarity score: 0.50925064, gold ranking: 4.72
# ----------------------------
# (book,literature) similarity score: 0.3822697, gold ranking: 7.53
# (book,article) similarity score: 0.6617341, gold ranking: 5.43
# ----------------------------
# (book,story) similarity score: 0.44187, gold ranking: 5.63
# (book,bible) similarity score: 0.69143414, gold ranking: 5.0
# ----------------------------
# (book,story) similarity score: 0.44187, gold ranking: 5.63
# (book,essay) similarity score: 0.50925064, gold ranking: 4.72
# ----------------------------
# (book,story) similarity score: 0.44187, gold ranking: 5.63
# (book,article) similarity score: 0.6617341, gold ranking: 5.43
# ----------------------------
# (book,bible) similarity score: 0.69143414, gold ranking: 5.0
# (book,information) similarity score: 0.28202838, gold ranking: 5.0
# ----------------------------
# (book,bible) similarity score: 0.69143414, gold ranking: 5.0
# (book,article) similarity score: 0.6617341, gold ranking: 5.43
# ----------------------------
# (book,topic) similarity score: 0.39124542, gold ranking: 2.07
# (book,information) similarity score: 0.28202838, gold ranking: 5.0
# ----------------------------
# (book,topic) similarity score: 0.39124542, gold ranking: 2.07
# (book,theme) similarity score: 0.2880932, gold ranking: 2.58
# ----------------------------
# (book,information) similarity score: 0.28202838, gold ranking: 5.0
# (book,essay) similarity score: 0.50925064, gold ranking: 4.72
# ----------------------------
# (book,information) similarity score: 0.28202838, gold ranking: 5.0
# (book,theme) similarity score: 0.2880932, gold ranking: 2.58
# ----------------------------
# (cat,lion) similarity score: 0.5149826, gold ranking: 6.75
# (cat,pet) similarity score: 0.68630344, gold ranking: 5.95
# ----------------------------
# (cat,lion) similarity score: 0.5149826, gold ranking: 6.75
# (cat,rabbit) similarity score: 0.61746407, gold ranking: 2.37
# ----------------------------
# (clothes,drawer) similarity score: 0.45731914, gold ranking: 3.02
# (clothes,fabric) similarity score: 0.20053138, gold ranking: 5.87
# ----------------------------
# (clothes,fabric) similarity score: 0.20053138, gold ranking: 5.87
# (clothes,button) similarity score: 0.3285368, gold ranking: 2.3
# ----------------------------
# (clothes,fabric) similarity score: 0.20053138, gold ranking: 5.87
# (clothes,coat) similarity score: 0.72592455, gold ranking: 5.35
# ----------------------------
# (clothes,fabric) similarity score: 0.20053138, gold ranking: 5.87
# (clothes,jacket) similarity score: 0.6304961, gold ranking: 5.15
# ----------------------------
# (create,make) similarity score: 0.25072032, gold ranking: 8.72
# (create,destroy) similarity score: 0.61493087, gold ranking: 0.63
# ----------------------------
# (cup,cone) similarity score: 0.26684368, gold ranking: 3.17
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# ----------------------------
# (cup,cone) similarity score: 0.26684368, gold ranking: 3.17
# (cup,substance) similarity score: 0.285552, gold ranking: 1.92
# ----------------------------
# (cup,jar) similarity score: 0.4786042, gold ranking: 5.13
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# ----------------------------
# (cup,jar) similarity score: 0.4786042, gold ranking: 5.13
# (cup,food) similarity score: 0.5374727, gold ranking: 5.0
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,artifact) similarity score: 0.1949294, gold ranking: 2.92
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,object) similarity score: 0.35448304, gold ranking: 3.69
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,entity) similarity score: 0.078538485, gold ranking: 2.15
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,food) similarity score: 0.5374727, gold ranking: 5.0
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,article) similarity score: 0.06254224, gold ranking: 2.4
# ----------------------------
# (cup,tableware) similarity score: 0.0, gold ranking: 6.85
# (cup,substance) similarity score: 0.285552, gold ranking: 1.92
# ----------------------------
# (cup,artifact) similarity score: 0.1949294, gold ranking: 2.92
# (cup,substance) similarity score: 0.285552, gold ranking: 1.92
# ----------------------------
# (cup,entity) similarity score: 0.078538485, gold ranking: 2.15
# (cup,article) similarity score: 0.06254224, gold ranking: 2.4
# ----------------------------
# (cup,entity) similarity score: 0.078538485, gold ranking: 2.15
# (cup,substance) similarity score: 0.285552, gold ranking: 1.92
# ----------------------------
# (cup,article) similarity score: 0.06254224, gold ranking: 2.4
# (cup,substance) similarity score: 0.285552, gold ranking: 1.92
# ----------------------------
# (drink,car) similarity score: 0.055269524, gold ranking: 3.04
# (drink,ear) similarity score: 0.21886331, gold ranking: 1.31
# ----------------------------
# (drink,mother) similarity score: 0.045949314, gold ranking: 2.65
# (drink,ear) similarity score: 0.21886331, gold ranking: 1.31
# ----------------------------
# (father,daughter) similarity score: 0.2661458, gold ranking: 2.62
# (father,god) similarity score: 0.24301094, gold ranking: 3.57
# ----------------------------
# (guy,stud) similarity score: 0.058971778, gold ranking: 5.83
# (guy,partner) similarity score: 0.19845502, gold ranking: 3.57
# ----------------------------
# (guy,stud) similarity score: 0.058971778, gold ranking: 5.83
# (guy,girl) similarity score: 0.44989, gold ranking: 3.33
# ----------------------------
# (guy,partner) similarity score: 0.19845502, gold ranking: 3.57
# (guy,girl) similarity score: 0.44989, gold ranking: 3.33
# ----------------------------
# (join,add) similarity score: -0.07628858, gold ranking: 8.1
# (join,marry) similarity score: 0.33709788, gold ranking: 5.35
# ----------------------------
# (join,add) similarity score: -0.07628858, gold ranking: 8.1
# (join,acquire) similarity score: 0.11247944, gold ranking: 2.85
# ----------------------------
# (king,princess) similarity score: 0.6311863, gold ranking: 3.27
# (king,rook) similarity score: 0.04893453, gold ranking: 5.92
# ----------------------------
# (king,rook) similarity score: 0.04893453, gold ranking: 5.92
# (king,cabbage) similarity score: 0.21771581, gold ranking: 0.23
# ----------------------------
# (lose,keep) similarity score: 0.33971208, gold ranking: 1.05
# (lose,get) similarity score: 0.36633027, gold ranking: 0.77
# ----------------------------
# (man,uncle) similarity score: 0.17189658, gold ranking: 3.92
# (man,father) similarity score: 0.12519865, gold ranking: 4.83
# ----------------------------
# (man,uncle) similarity score: 0.17189658, gold ranking: 3.92
# (man,child) similarity score: 0.038949095, gold ranking: 4.13
# ----------------------------
# (man,uncle) similarity score: 0.17189658, gold ranking: 3.92
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# ----------------------------
# (man,uncle) similarity score: 0.17189658, gold ranking: 3.92
# (man,husband) similarity score: 0.16628645, gold ranking: 5.32
# ----------------------------
# (man,uncle) similarity score: 0.17189658, gold ranking: 3.92
# (man,warrior) similarity score: 0.15751775, gold ranking: 4.72
# ----------------------------
# (man,uncle) similarity score: 0.17189658, gold ranking: 3.92
# (man,governor) similarity score: -0.02044457, gold ranking: 5.25
# ----------------------------
# (man,father) similarity score: 0.12519865, gold ranking: 4.83
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# ----------------------------
# (man,father) similarity score: 0.12519865, gold ranking: 4.83
# (man,warrior) similarity score: 0.15751775, gold ranking: 4.72
# ----------------------------
# (man,father) similarity score: 0.12519865, gold ranking: 4.83
# (man,governor) similarity score: -0.02044457, gold ranking: 5.25
# ----------------------------
# (man,child) similarity score: 0.038949095, gold ranking: 4.13
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# ----------------------------
# (man,child) similarity score: 0.038949095, gold ranking: 4.13
# (man,sentry) similarity score: 0.049065627, gold ranking: 3.25
# ----------------------------
# (man,child) similarity score: 0.038949095, gold ranking: 4.13
# (man,governor) similarity score: -0.02044457, gold ranking: 5.25
# ----------------------------
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# (man,sentry) similarity score: 0.049065627, gold ranking: 3.25
# ----------------------------
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# (man,husband) similarity score: 0.16628645, gold ranking: 5.32
# ----------------------------
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# (man,warrior) similarity score: 0.15751775, gold ranking: 4.72
# ----------------------------
# (man,victor) similarity score: 0.18959662, gold ranking: 1.9
# (man,governor) similarity score: -0.02044457, gold ranking: 5.25
# ----------------------------
# (man,sentry) similarity score: 0.049065627, gold ranking: 3.25
# (man,governor) similarity score: -0.02044457, gold ranking: 5.25
# ----------------------------
# (man,warrior) similarity score: 0.15751775, gold ranking: 4.72
# (man,governor) similarity score: -0.02044457, gold ranking: 5.25
# ----------------------------
# (meat,bacon) similarity score: 0.19146012, gold ranking: 5.8
# (meat,bread) similarity score: 0.62685525, gold ranking: 1.67
# ----------------------------
# (media,radio) similarity score: 0.0, gold ranking: 7.42
# (media,trading) similarity score: 0.0, gold ranking: 3.88
# ----------------------------
# (money,salary) similarity score: 0.4202441, gold ranking: 7.88
# (money,diamond) similarity score: 0.521816, gold ranking: 3.42
# ----------------------------
# (precedent,antecedent) similarity score: 0.3249049, gold ranking: 6.04
# (precedent,cognition) similarity score: 0.704211, gold ranking: 2.81
# ----------------------------
# (precedent,information) similarity score: 0.15642388, gold ranking: 3.85
# (precedent,cognition) similarity score: 0.704211, gold ranking: 2.81
# ----------------------------
# (situation,conclusion) similarity score: 0.24237569, gold ranking: 4.81
# (situation,isolation) similarity score: 0.2824348, gold ranking: 3.88
# ----------------------------
# (street,alley) similarity score: 0.5412376, gold ranking: 5.48
# (street,place) similarity score: 0.06728634, gold ranking: 6.44
# ----------------------------
# (street,alley) similarity score: 0.5412376, gold ranking: 5.48
# (street,avenue) similarity score: 0.31038275, gold ranking: 8.88
# ----------------------------
# (street,car) similarity score: 0.30437398, gold ranking: 2.38
# (street,place) similarity score: 0.06728634, gold ranking: 6.44
# ----------------------------
# (take,obtain) similarity score: 0.18390839, gold ranking: 7.1
# (take,carry) similarity score: 0.5134747, gold ranking: 5.23
# ----------------------------
# (take,obtain) similarity score: 0.18390839, gold ranking: 7.1
# (take,deliver) similarity score: 0.21829355, gold ranking: 4.37
# ----------------------------
# (take,obtain) similarity score: 0.18390839, gold ranking: 7.1
# (take,leave) similarity score: 0.29184812, gold ranking: 2.47
# ----------------------------
# (take,receive) similarity score: 0.12389554, gold ranking: 5.08
# (take,deliver) similarity score: 0.21829355, gold ranking: 4.37
# ----------------------------
# (take,receive) similarity score: 0.12389554, gold ranking: 5.08
# (take,leave) similarity score: 0.29184812, gold ranking: 2.47
# ----------------------------
# (take,deliver) similarity score: 0.21829355, gold ranking: 4.37
# (take,leave) similarity score: 0.29184812, gold ranking: 2.47
# ----------------------------
# (tiger,carnivore) similarity score: 0.13775249, gold ranking: 7.08
# (tiger,mammal) similarity score: 0.29462668, gold ranking: 6.85
# ----------------------------
# (tiger,carnivore) similarity score: 0.13775249, gold ranking: 7.08
# (tiger,animal) similarity score: 0.4948945, gold ranking: 7.0
# ----------------------------
# (tiger,carnivore) similarity score: 0.13775249, gold ranking: 7.08
# (tiger,organism) similarity score: 0.17291264, gold ranking: 4.77
# ----------------------------
# (tiger,organism) similarity score: 0.17291264, gold ranking: 4.77
# (tiger,fauna) similarity score: 0.082916595, gold ranking: 5.62
# ----------------------------
# (bad,immoral) similarity score: 0.2458354, gold ranking: 7.62
# (bad,great) similarity score: 0.31168896, gold ranking: 0.35
# ----------------------------
# Accuracy: 0.5703703703703704

# %%
word2vec_test_similarities = []

for id, word1, word2 in test_document_similarities:
    similarity_score = get_similarity_word2vec(word1, word2)
    word2vec_test_similarities.append((id, similarity_score))

filename = "10749545-Task1-method-b.csv"
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)

    for id, similarity in word2vec_test_similarities:
        row = [id] + [similarity]
        writer.writerow(row)
