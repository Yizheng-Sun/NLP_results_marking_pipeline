# %%
import pandas as pd
import nltk
import string
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
from collections import defaultdict
from scipy.sparse import coo_array, csr_array
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
vocab = set()
tokens = []

# %%
def get_vocab_tokens(text):
  row_tokens = word_tokenize(text)
  tokens.append(row_tokens)
  vocab.update(row_tokens)

# %%
pd.read_csv('data/Training-dataset.csv')['plot_synopsis'].apply(get_vocab_tokens)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 8252    None
# 8253    None
# 8254    None
# 8255    None
# 8256    None
# Name: plot_synopsis, Length: 8257, dtype: object

# %%
vocab_list = sorted(vocab)
index_from_word = {word:index for (index, word) in enumerate(vocab_list)}
word_from_index = {index:word for (index, word) in enumerate(vocab_list)}

# %% [markdown]
# ###Method A

# %%
def get_term_context_matrix(tokens, window_size):
  contextfreqs = defaultdict(int)

  # iterate through each token in each document
  for document in tokens:
    for i in range(len(document)):
      # iterate through each token in context (+/- window_size on each size)
      context_start = max(i-window_size, 0)
      context_stop = min(i+window_size+1, len(document))
      for context_i in range(context_start, context_stop):
        if context_i == i: continue # don't include the token of interest in the context
        # incremenet count for that term and context word
        contextfreqs[(index_from_word[document[i]], index_from_word[document[context_i]])] += 1

  # convert key tuples to two lists, one for row, one for column
  keys = np.array(list(contextfreqs.keys())).T.tolist()
  rows = keys[0]
  columns = keys[1]

  # create sparse term-context matrix
  return coo_array((list(contextfreqs.values()), (rows, columns)), shape=(len(vocab), len(vocab))).tocsr()

# %%
def calculate_ppmi(term_context, smoothing):
  # sum of every frequency
  smoothed_sum = term_context.sum() + (smoothing * term_context.shape[0] * term_context.shape[1])

  # normalise term-context matrix to get probabilities
  p_term_context = term_context.copy()
  p_term_context.data = (term_context.data + smoothing)/smoothed_sum

  # row and column probability sums with smoothing
  p_terms_sum = (term_context.sum(axis=1) + (smoothing * term_context.shape[1]))/smoothed_sum
  p_context_sum = (term_context.sum(axis=0) + (smoothing * term_context.shape[0]))/smoothed_sum

  # calculate ppmi
  ppmi_term_context = p_term_context.copy()
  ppmi_term_context.data = np.log2((p_term_context/(p_terms_sum * p_context_sum)).data) # calculate pmi values
  ppmi_term_context = ppmi_term_context.maximum(0)  # replace negative pmi values with 0 to get ppmi
  return ppmi_term_context

# %%
# calculate ppmi
window_size = 3
add_smoothing = 2

term_context = get_term_context_matrix(tokens, window_size)
ppmi_term_context = calculate_ppmi(term_context, add_smoothing)

# %%
def ppmi_vector(word):
  # tokenise in case input is actually multi-word
  word_tokens = [ppmi_term_context[[index_from_word[t]],:] for t in word_tokenize(word) if t in vocab]

  # if word_tokens is empty
  if not word_tokens:
    return None

  # sum the representation vectors
  return np.array(word_tokens).sum(axis=0)

# %%
def row_similarity(row, vector_func):
  id = row[0]

  # get the vector representations for each word
  word1 = vector_func(row[1])
  word2 = vector_func(row[2])

  if (word1 is not None) and (word2 is not None):
    similarity = cosine_similarity(word1, word2).item()
  else:
    similarity = 0.5
  return [id, similarity]

# %%
def get_results(inputf, outputf, vector_func, run_eval=False):
  # read in validation/test dataset
  input = pd.read_csv(inputf, header=None, usecols=[0, 1, 2])

  # calculate similarity for each word pair
  results = input.apply(row_similarity, axis=1, result_type='expand', vector_func=vector_func)
  results[0] = results[0].astype('int') # change ids back to ints

  # write results to csv
  results.to_csv(outputf, header=False, index=False)

  # run evaluation script
  if run_eval:
    # !python data/task1_eval_script_student_version.py {outputf} {inputf}

# %%
get_results('data/Task-1-validation-dataset.csv', 'data/10491450-Task1-method-a-validation.csv', ppmi_vector, run_eval=True)
# Out:
# The following simalarity scores may need checking:
# (acquire,obtain) similarity score: 0.17012102010353683, gold ranking: 8.57
# (acquire,find) similarity score: 0.17115432656301724, gold ranking: 6.38
# ----------------------------
# (apple,sauce) similarity score: 0.01886705895299194, gold ranking: 1.43
# (apple,lemon) similarity score: 0.010063297230987296, gold ranking: 4.05
# ----------------------------
# (area,region) similarity score: 0.20092632914782163, gold ranking: 9.47
# (area,corner) similarity score: 0.29451624292394335, gold ranking: 2.07
# ----------------------------
# (arm,shoulder) similarity score: 0.41052417978217554, gold ranking: 4.85
# (arm,body) similarity score: 0.46262796295190506, gold ranking: 4.05
# ----------------------------
# (arm,shoulder) similarity score: 0.41052417978217554, gold ranking: 4.85
# (arm,neck) similarity score: 0.4821267246409147, gold ranking: 1.58
# ----------------------------
# (arm,body) similarity score: 0.46262796295190506, gold ranking: 4.05
# (arm,neck) similarity score: 0.4821267246409147, gold ranking: 1.58
# ----------------------------
# (arm,vein) similarity score: 0.041469721375944485, gold ranking: 3.65
# (arm,knee) similarity score: 0.19877589659662953, gold ranking: 2.75
# ----------------------------
# (arm,vein) similarity score: 0.041469721375944485, gold ranking: 3.65
# (arm,neck) similarity score: 0.4821267246409147, gold ranking: 1.58
# ----------------------------
# (arm,knee) similarity score: 0.19877589659662953, gold ranking: 2.75
# (arm,bone) similarity score: 0.15148766916112122, gold ranking: 3.83
# ----------------------------
# (arm,knee) similarity score: 0.19877589659662953, gold ranking: 2.75
# (arm,neck) similarity score: 0.4821267246409147, gold ranking: 1.58
# ----------------------------
# (arm,bone) similarity score: 0.15148766916112122, gold ranking: 3.83
# (arm,neck) similarity score: 0.4821267246409147, gold ranking: 1.58
# ----------------------------
# (bath,trick) similarity score: 0.13963063284570457, gold ranking: 0.58
# (bath,wife) similarity score: 0.22999872523984857, gold ranking: 0.48
# ----------------------------
# (bed,bedroom) similarity score: 0.5311485074293558, gold ranking: 3.4
# (bed,crib) similarity score: 0.1221064384094919, gold ranking: 7.3
# ----------------------------
# (bed,bedroom) similarity score: 0.5311485074293558, gold ranking: 3.4
# (bed,chair) similarity score: 0.45751889335320156, gold ranking: 3.5
# ----------------------------
# (bed,blanket) similarity score: 0.20204189205094136, gold ranking: 3.02
# (bed,crib) similarity score: 0.1221064384094919, gold ranking: 7.3
# ----------------------------
# (bed,blanket) similarity score: 0.20204189205094136, gold ranking: 3.02
# (bed,hospital) similarity score: 0.5295385136605002, gold ranking: 0.92
# ----------------------------
# (bed,crib) similarity score: 0.1221064384094919, gold ranking: 7.3
# (bed,hospital) similarity score: 0.5295385136605002, gold ranking: 0.92
# ----------------------------
# (bed,crib) similarity score: 0.1221064384094919, gold ranking: 7.3
# (bed,chair) similarity score: 0.45751889335320156, gold ranking: 3.5
# ----------------------------
# (bed,hospital) similarity score: 0.5295385136605002, gold ranking: 0.92
# (bed,chair) similarity score: 0.45751889335320156, gold ranking: 3.5
# ----------------------------
# (bone,jaw) similarity score: 0.07898198868770794, gold ranking: 4.17
# (bone,knee) similarity score: 0.0658219018908039, gold ranking: 4.17
# ----------------------------
# (bone,jaw) similarity score: 0.07898198868770794, gold ranking: 4.17
# (bone,neck) similarity score: 0.12563220729245916, gold ranking: 2.53
# ----------------------------
# (bone,ankle) similarity score: 0.05451526609656354, gold ranking: 3.82
# (bone,neck) similarity score: 0.12563220729245916, gold ranking: 2.53
# ----------------------------
# (bone,knee) similarity score: 0.0658219018908039, gold ranking: 4.17
# (bone,neck) similarity score: 0.12563220729245916, gold ranking: 2.53
# ----------------------------
# (bone,neck) similarity score: 0.12563220729245916, gold ranking: 2.53
# (bone,elbow) similarity score: 0.020933511531484237, gold ranking: 3.78
# ----------------------------
# (book,literature) similarity score: 0.09696981132933702, gold ranking: 7.53
# (book,story) similarity score: 0.5125443189810519, gold ranking: 5.63
# ----------------------------
# (book,literature) similarity score: 0.09696981132933702, gold ranking: 7.53
# (book,bible) similarity score: 0.09944859223568017, gold ranking: 5.0
# ----------------------------
# (book,literature) similarity score: 0.09696981132933702, gold ranking: 7.53
# (book,information) similarity score: 0.4218361725331451, gold ranking: 5.0
# ----------------------------
# (book,literature) similarity score: 0.09696981132933702, gold ranking: 7.53
# (book,article) similarity score: 0.33705954495343304, gold ranking: 5.43
# ----------------------------
# (book,literature) similarity score: 0.09696981132933702, gold ranking: 7.53
# (book,theme) similarity score: 0.14492121975735509, gold ranking: 2.58
# ----------------------------
# (book,bible) similarity score: 0.09944859223568017, gold ranking: 5.0
# (book,theme) similarity score: 0.14492121975735509, gold ranking: 2.58
# ----------------------------
# (book,information) similarity score: 0.4218361725331451, gold ranking: 5.0
# (book,article) similarity score: 0.33705954495343304, gold ranking: 5.43
# ----------------------------
# (book,essay) similarity score: 0.09265872438002554, gold ranking: 4.72
# (book,theme) similarity score: 0.14492121975735509, gold ranking: 2.58
# ----------------------------
# (cat,lion) similarity score: 0.1322984696021074, gold ranking: 6.75
# (cat,pet) similarity score: 0.26249844895033575, gold ranking: 5.95
# ----------------------------
# (cat,lion) similarity score: 0.1322984696021074, gold ranking: 6.75
# (cat,rabbit) similarity score: 0.23877941402529393, gold ranking: 2.37
# ----------------------------
# (clothes,drawer) similarity score: 0.1641108245968447, gold ranking: 3.02
# (clothes,fabric) similarity score: 0.07542457467875427, gold ranking: 5.87
# ----------------------------
# (clothes,fabric) similarity score: 0.07542457467875427, gold ranking: 5.87
# (clothes,button) similarity score: 0.10424425499573574, gold ranking: 2.3
# ----------------------------
# (clothes,fabric) similarity score: 0.07542457467875427, gold ranking: 5.87
# (clothes,coat) similarity score: 0.36511507934873527, gold ranking: 5.35
# ----------------------------
# (clothes,fabric) similarity score: 0.07542457467875427, gold ranking: 5.87
# (clothes,jacket) similarity score: 0.3174170847890023, gold ranking: 5.15
# ----------------------------
# (cup,cone) similarity score: 0.0, gold ranking: 3.17
# (cup,artifact) similarity score: 0.048507376645969075, gold ranking: 2.92
# ----------------------------
# (cup,cone) similarity score: 0.0, gold ranking: 3.17
# (cup,entity) similarity score: 0.03380544614457189, gold ranking: 2.15
# ----------------------------
# (cup,cone) similarity score: 0.0, gold ranking: 3.17
# (cup,article) similarity score: 0.05806009207400496, gold ranking: 2.4
# ----------------------------
# (cup,cone) similarity score: 0.0, gold ranking: 3.17
# (cup,substance) similarity score: 0.05453390081645626, gold ranking: 1.92
# ----------------------------
# (cup,jar) similarity score: 0.08037836671743849, gold ranking: 5.13
# (cup,object) similarity score: 0.10073656203664767, gold ranking: 3.69
# ----------------------------
# (cup,jar) similarity score: 0.08037836671743849, gold ranking: 5.13
# (cup,food) similarity score: 0.20355252473172458, gold ranking: 5.0
# ----------------------------
# (cup,artifact) similarity score: 0.048507376645969075, gold ranking: 2.92
# (cup,article) similarity score: 0.05806009207400496, gold ranking: 2.4
# ----------------------------
# (cup,artifact) similarity score: 0.048507376645969075, gold ranking: 2.92
# (cup,substance) similarity score: 0.05453390081645626, gold ranking: 1.92
# ----------------------------
# (cup,entity) similarity score: 0.03380544614457189, gold ranking: 2.15
# (cup,substance) similarity score: 0.05453390081645626, gold ranking: 1.92
# ----------------------------
# (father,parent) similarity score: 0.1900712920421879, gold ranking: 7.07
# (father,daughter) similarity score: 0.6365691289307198, gold ranking: 2.62
# ----------------------------
# (father,parent) similarity score: 0.1900712920421879, gold ranking: 7.07
# (father,brother) similarity score: 0.6641199304342512, gold ranking: 4.2
# ----------------------------
# (father,parent) similarity score: 0.1900712920421879, gold ranking: 7.07
# (father,god) similarity score: 0.19737665966565085, gold ranking: 3.57
# ----------------------------
# (father,daughter) similarity score: 0.6365691289307198, gold ranking: 2.62
# (father,god) similarity score: 0.19737665966565085, gold ranking: 3.57
# ----------------------------
# (flower,violet) similarity score: 0.013637992997488753, gold ranking: 6.95
# (flower,bulb) similarity score: 0.021304679158756102, gold ranking: 4.48
# ----------------------------
# (flower,violet) similarity score: 0.013637992997488753, gold ranking: 6.95
# (flower,endurance) similarity score: 0.019460907838117526, gold ranking: 0.4
# ----------------------------
# (guy,stud) similarity score: 0.03490271394093253, gold ranking: 5.83
# (guy,partner) similarity score: 0.31441538426222887, gold ranking: 3.57
# ----------------------------
# (guy,stud) similarity score: 0.03490271394093253, gold ranking: 5.83
# (guy,girl) similarity score: 0.5275663297197791, gold ranking: 3.33
# ----------------------------
# (guy,partner) similarity score: 0.31441538426222887, gold ranking: 3.57
# (guy,girl) similarity score: 0.5275663297197791, gold ranking: 3.33
# ----------------------------
# (join,add) similarity score: 0.1330685139578215, gold ranking: 8.1
# (join,marry) similarity score: 0.46512245529917784, gold ranking: 5.35
# ----------------------------
# (king,princess) similarity score: 0.1901493270377276, gold ranking: 3.27
# (king,rook) similarity score: 0.04151453169758501, gold ranking: 5.92
# ----------------------------
# (lose,fail) similarity score: 0.28431708350817414, gold ranking: 7.33
# (lose,keep) similarity score: 0.408460138101208, gold ranking: 1.05
# ----------------------------
# (lose,fail) similarity score: 0.28431708350817414, gold ranking: 7.33
# (lose,get) similarity score: 0.440721621417091, gold ranking: 0.77
# ----------------------------
# (lose,keep) similarity score: 0.408460138101208, gold ranking: 1.05
# (lose,get) similarity score: 0.440721621417091, gold ranking: 0.77
# ----------------------------
# (man,uncle) similarity score: 0.4215270351613525, gold ranking: 3.92
# (man,warrior) similarity score: 0.23157101394236207, gold ranking: 4.72
# ----------------------------
# (man,uncle) similarity score: 0.4215270351613525, gold ranking: 3.92
# (man,governor) similarity score: 0.201723581228033, gold ranking: 5.25
# ----------------------------
# (man,father) similarity score: 0.6805270709868225, gold ranking: 4.83
# (man,husband) similarity score: 0.6008762724673111, gold ranking: 5.32
# ----------------------------
# (man,father) similarity score: 0.6805270709868225, gold ranking: 4.83
# (man,governor) similarity score: 0.201723581228033, gold ranking: 5.25
# ----------------------------
# (man,child) similarity score: 0.5808261899602276, gold ranking: 4.13
# (man,warrior) similarity score: 0.23157101394236207, gold ranking: 4.72
# ----------------------------
# (man,child) similarity score: 0.5808261899602276, gold ranking: 4.13
# (man,governor) similarity score: 0.201723581228033, gold ranking: 5.25
# ----------------------------
# (man,warrior) similarity score: 0.23157101394236207, gold ranking: 4.72
# (man,governor) similarity score: 0.201723581228033, gold ranking: 5.25
# ----------------------------
# (meat,bacon) similarity score: 0.07329355049078062, gold ranking: 5.8
# (meat,bread) similarity score: 0.09422585217082018, gold ranking: 1.67
# ----------------------------
# (money,salary) similarity score: 0.17103034371918813, gold ranking: 7.88
# (money,diamond) similarity score: 0.27686659054255075, gold ranking: 3.42
# ----------------------------
# (precedent,cognition) similarity score: 0.0, gold ranking: 2.81
# (precedent,group) similarity score: 0.02887046984860775, gold ranking: 1.77
# ----------------------------
# (street,alley) similarity score: 0.38345142186540965, gold ranking: 5.48
# (street,car) similarity score: 0.5366103565632117, gold ranking: 2.38
# ----------------------------
# (street,alley) similarity score: 0.38345142186540965, gold ranking: 5.48
# (street,avenue) similarity score: 0.030990804115835043, gold ranking: 8.88
# ----------------------------
# (street,car) similarity score: 0.5366103565632117, gold ranking: 2.38
# (street,place) similarity score: 0.4655110043672569, gold ranking: 6.44
# ----------------------------
# (street,car) similarity score: 0.5366103565632117, gold ranking: 2.38
# (street,avenue) similarity score: 0.030990804115835043, gold ranking: 8.88
# ----------------------------
# (street,place) similarity score: 0.4655110043672569, gold ranking: 6.44
# (street,avenue) similarity score: 0.030990804115835043, gold ranking: 8.88
# ----------------------------
# (take,obtain) similarity score: 0.252890031158354, gold ranking: 7.1
# (take,receive) similarity score: 0.3456307553272596, gold ranking: 5.08
# ----------------------------
# (take,obtain) similarity score: 0.252890031158354, gold ranking: 7.1
# (take,carry) similarity score: 0.43380747010131987, gold ranking: 5.23
# ----------------------------
# (take,obtain) similarity score: 0.252890031158354, gold ranking: 7.1
# (take,deliver) similarity score: 0.338543816019638, gold ranking: 4.37
# ----------------------------
# (take,obtain) similarity score: 0.252890031158354, gold ranking: 7.1
# (take,leave) similarity score: 0.6705024635315169, gold ranking: 2.47
# ----------------------------
# (take,receive) similarity score: 0.3456307553272596, gold ranking: 5.08
# (take,leave) similarity score: 0.6705024635315169, gold ranking: 2.47
# ----------------------------
# (take,carry) similarity score: 0.43380747010131987, gold ranking: 5.23
# (take,leave) similarity score: 0.6705024635315169, gold ranking: 2.47
# ----------------------------
# (take,deliver) similarity score: 0.338543816019638, gold ranking: 4.37
# (take,leave) similarity score: 0.6705024635315169, gold ranking: 2.47
# ----------------------------
# (tiger,feline) similarity score: 0.011608236814992953, gold ranking: 8.0
# (tiger,carnivore) similarity score: 0.5, gold ranking: 7.08
# ----------------------------
# (tiger,feline) similarity score: 0.011608236814992953, gold ranking: 8.0
# (tiger,animal) similarity score: 0.10903914549787089, gold ranking: 7.0
# ----------------------------
# (tiger,mammal) similarity score: 0.0, gold ranking: 6.85
# (tiger,organism) similarity score: 0.010589759257411128, gold ranking: 4.77
# ----------------------------
# (tiger,mammal) similarity score: 0.0, gold ranking: 6.85
# (tiger,fauna) similarity score: 0.0011776112486284178, gold ranking: 5.62
# ----------------------------
# (tiger,organism) similarity score: 0.010589759257411128, gold ranking: 4.77
# (tiger,fauna) similarity score: 0.0011776112486284178, gold ranking: 5.62
# ----------------------------
# (happy,cheerful) similarity score: 0.09428513198692662, gold ranking: 9.55
# (happy,young) similarity score: 0.423597245316047, gold ranking: 2.0
# ----------------------------
# (bad,immoral) similarity score: 0.09116214432789589, gold ranking: 7.62
# (bad,great) similarity score: 0.4363388367255331, gold ranking: 0.35
# ----------------------------
# Accuracy: 0.6666666666666667

# %% [markdown]
# ###Method B

# %%
w2v_model = Word2Vec(tokens, vector_size=100, window=3, min_count=1, sample=0.005)

# %%
def word2vec_vector(word):
  wv = w2v_model.wv

  # tokenise in case input is actually multi-word
  word_tokens = [wv[t].reshape((1, -1)) for t in word_tokenize(word) if wv.has_index_for(t)]

  # if word_tokens is empty
  if not word_tokens:
    return None

  # sum the representation vectors
  return np.array(word_tokens).sum(axis=0)

# %%
get_results('data/Task-1-validation-dataset.csv', 'data/10491450-Task1-method-b-validation.csv', word2vec_vector, run_eval=True)
# Out:
# The following simalarity scores may need checking:
# (absorb,learn) similarity score: 0.3720565736293793, gold ranking: 5.48
# (absorb,withdraw) similarity score: 0.7458263039588928, gold ranking: 2.97
# ----------------------------
# (acquire,get) similarity score: 0.5517366528511047, gold ranking: 8.82
# (acquire,obtain) similarity score: 0.8811715245246887, gold ranking: 8.57
# ----------------------------
# (apple,sauce) similarity score: 0.5571714043617249, gold ranking: 1.43
# (apple,lemon) similarity score: 0.4903217554092407, gold ranking: 4.05
# ----------------------------
# (apple,lemon) similarity score: 0.4903217554092407, gold ranking: 4.05
# (apple,sunshine) similarity score: 0.5502339005470276, gold ranking: 0.58
# ----------------------------
# (arm,shoulder) similarity score: 0.8811830282211304, gold ranking: 4.85
# (arm,neck) similarity score: 0.8945770859718323, gold ranking: 1.58
# ----------------------------
# (arm,body) similarity score: 0.7463340163230896, gold ranking: 4.05
# (arm,neck) similarity score: 0.8945770859718323, gold ranking: 1.58
# ----------------------------
# (arm,vein) similarity score: 0.424185186624527, gold ranking: 3.65
# (arm,knee) similarity score: 0.731607973575592, gold ranking: 2.75
# ----------------------------
# (arm,vein) similarity score: 0.424185186624527, gold ranking: 3.65
# (arm,neck) similarity score: 0.8945770859718323, gold ranking: 1.58
# ----------------------------
# (arm,knee) similarity score: 0.731607973575592, gold ranking: 2.75
# (arm,bone) similarity score: 0.5986229777336121, gold ranking: 3.83
# ----------------------------
# (arm,knee) similarity score: 0.731607973575592, gold ranking: 2.75
# (arm,neck) similarity score: 0.8945770859718323, gold ranking: 1.58
# ----------------------------
# (arm,bone) similarity score: 0.5986229777336121, gold ranking: 3.83
# (arm,neck) similarity score: 0.8945770859718323, gold ranking: 1.58
# ----------------------------
# (bath,trick) similarity score: 0.38595032691955566, gold ranking: 0.58
# (bath,balloon) similarity score: 0.6300885081291199, gold ranking: 0.4
# ----------------------------
# (bath,wife) similarity score: 0.29595229029655457, gold ranking: 0.48
# (bath,balloon) similarity score: 0.6300885081291199, gold ranking: 0.4
# ----------------------------
# (bed,bedroom) similarity score: 0.7860239744186401, gold ranking: 3.4
# (bed,crib) similarity score: 0.6472132802009583, gold ranking: 7.3
# ----------------------------
# (bed,blanket) similarity score: 0.5915021896362305, gold ranking: 3.02
# (bed,hospital) similarity score: 0.6457388401031494, gold ranking: 0.92
# ----------------------------
# (bed,crib) similarity score: 0.6472132802009583, gold ranking: 7.3
# (bed,chair) similarity score: 0.8170384168624878, gold ranking: 3.5
# ----------------------------
# (bird,turkey) similarity score: 0.7009053230285645, gold ranking: 6.58
# (bird,hen) similarity score: 0.46767154335975647, gold ranking: 7.03
# ----------------------------
# (bird,turkey) similarity score: 0.7009053230285645, gold ranking: 6.58
# (bird,cock) similarity score: 0.18577492237091064, gold ranking: 7.1
# ----------------------------
# (bird,hen) similarity score: 0.46767154335975647, gold ranking: 7.03
# (bird,cock) similarity score: 0.18577492237091064, gold ranking: 7.1
# ----------------------------
# (bone,jaw) similarity score: 0.6862307190895081, gold ranking: 4.17
# (bone,knee) similarity score: 0.5640600919723511, gold ranking: 4.17
# ----------------------------
# (bone,jaw) similarity score: 0.6862307190895081, gold ranking: 4.17
# (bone,teeth) similarity score: 0.6669020056724548, gold ranking: 4.17
# ----------------------------
# (bone,ankle) similarity score: 0.5111476182937622, gold ranking: 3.82
# (bone,neck) similarity score: 0.577237606048584, gold ranking: 2.53
# ----------------------------
# (bone,knee) similarity score: 0.5640600919723511, gold ranking: 4.17
# (bone,neck) similarity score: 0.577237606048584, gold ranking: 2.53
# ----------------------------
# (bone,neck) similarity score: 0.577237606048584, gold ranking: 2.53
# (bone,elbow) similarity score: 0.5040144324302673, gold ranking: 3.78
# ----------------------------
# (book,literature) similarity score: 0.43435582518577576, gold ranking: 7.53
# (book,story) similarity score: 0.6762621402740479, gold ranking: 5.63
# ----------------------------
# (book,literature) similarity score: 0.43435582518577576, gold ranking: 7.53
# (book,bible) similarity score: 0.5601714849472046, gold ranking: 5.0
# ----------------------------
# (book,literature) similarity score: 0.43435582518577576, gold ranking: 7.53
# (book,topic) similarity score: 0.5103204846382141, gold ranking: 2.07
# ----------------------------
# (book,literature) similarity score: 0.43435582518577576, gold ranking: 7.53
# (book,information) similarity score: 0.4901812970638275, gold ranking: 5.0
# ----------------------------
# (book,literature) similarity score: 0.43435582518577576, gold ranking: 7.53
# (book,article) similarity score: 0.727725088596344, gold ranking: 5.43
# ----------------------------
# (book,literature) similarity score: 0.43435582518577576, gold ranking: 7.53
# (book,theme) similarity score: 0.6197977662086487, gold ranking: 2.58
# ----------------------------
# (book,story) similarity score: 0.6762621402740479, gold ranking: 5.63
# (book,article) similarity score: 0.727725088596344, gold ranking: 5.43
# ----------------------------
# (book,bible) similarity score: 0.5601714849472046, gold ranking: 5.0
# (book,information) similarity score: 0.4901812970638275, gold ranking: 5.0
# ----------------------------
# (book,bible) similarity score: 0.5601714849472046, gold ranking: 5.0
# (book,theme) similarity score: 0.6197977662086487, gold ranking: 2.58
# ----------------------------
# (book,topic) similarity score: 0.5103204846382141, gold ranking: 2.07
# (book,information) similarity score: 0.4901812970638275, gold ranking: 5.0
# ----------------------------
# (book,topic) similarity score: 0.5103204846382141, gold ranking: 2.07
# (book,essay) similarity score: 0.3310556709766388, gold ranking: 4.72
# ----------------------------
# (book,information) similarity score: 0.4901812970638275, gold ranking: 5.0
# (book,theme) similarity score: 0.6197977662086487, gold ranking: 2.58
# ----------------------------
# (book,essay) similarity score: 0.3310556709766388, gold ranking: 4.72
# (book,theme) similarity score: 0.6197977662086487, gold ranking: 2.58
# ----------------------------
# (boy,brother) similarity score: 0.4445316791534424, gold ranking: 6.67
# (boy,soldier) similarity score: 0.6817000508308411, gold ranking: 2.15
# ----------------------------
# (cat,lion) similarity score: 0.689358115196228, gold ranking: 6.75
# (cat,rabbit) similarity score: 0.7928626537322998, gold ranking: 2.37
# ----------------------------
# (cat,pet) similarity score: 0.599148154258728, gold ranking: 5.95
# (cat,rabbit) similarity score: 0.7928626537322998, gold ranking: 2.37
# ----------------------------
# (clothes,drawer) similarity score: 0.4715668559074402, gold ranking: 3.02
# (clothes,fabric) similarity score: 0.44452476501464844, gold ranking: 5.87
# ----------------------------
# (clothes,fabric) similarity score: 0.44452476501464844, gold ranking: 5.87
# (clothes,coat) similarity score: 0.7342456579208374, gold ranking: 5.35
# ----------------------------
# (clothes,fabric) similarity score: 0.44452476501464844, gold ranking: 5.87
# (clothes,jacket) similarity score: 0.72319495677948, gold ranking: 5.15
# ----------------------------
# (create,make) similarity score: 0.653069019317627, gold ranking: 8.72
# (create,destroy) similarity score: 0.6696563959121704, gold ranking: 0.63
# ----------------------------
# (cup,cone) similarity score: 0.3869721293449402, gold ranking: 3.17
# (cup,artifact) similarity score: 0.4136257767677307, gold ranking: 2.92
# ----------------------------
# (cup,cone) similarity score: 0.3869721293449402, gold ranking: 3.17
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (cup,jar) similarity score: 0.7782390713691711, gold ranking: 5.13
# (cup,tableware) similarity score: 0.5, gold ranking: 6.85
# ----------------------------
# (cup,tableware) similarity score: 0.5, gold ranking: 6.85
# (cup,object) similarity score: 0.5051628947257996, gold ranking: 3.69
# ----------------------------
# (cup,tableware) similarity score: 0.5, gold ranking: 6.85
# (cup,food) similarity score: 0.5649904012680054, gold ranking: 5.0
# ----------------------------
# (cup,tableware) similarity score: 0.5, gold ranking: 6.85
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (cup,artifact) similarity score: 0.4136257767677307, gold ranking: 2.92
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (cup,object) similarity score: 0.5051628947257996, gold ranking: 3.69
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (cup,entity) similarity score: 0.3120485544204712, gold ranking: 2.15
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (cup,food) similarity score: 0.5649904012680054, gold ranking: 5.0
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (cup,article) similarity score: 0.381030410528183, gold ranking: 2.4
# (cup,substance) similarity score: 0.5806121230125427, gold ranking: 1.92
# ----------------------------
# (drink,car) similarity score: 0.42494022846221924, gold ranking: 3.04
# (drink,ear) similarity score: 0.4926932156085968, gold ranking: 1.31
# ----------------------------
# (drink,mother) similarity score: 0.37713882327079773, gold ranking: 2.65
# (drink,ear) similarity score: 0.4926932156085968, gold ranking: 1.31
# ----------------------------
# (father,parent) similarity score: 0.7413786053657532, gold ranking: 7.07
# (father,daughter) similarity score: 0.7728619575500488, gold ranking: 2.62
# ----------------------------
# (father,parent) similarity score: 0.7413786053657532, gold ranking: 7.07
# (father,brother) similarity score: 0.8189697861671448, gold ranking: 4.2
# ----------------------------
# (father,daughter) similarity score: 0.7728619575500488, gold ranking: 2.62
# (father,god) similarity score: 0.33157631754875183, gold ranking: 3.57
# ----------------------------
# (flower,violet) similarity score: 0.358908087015152, gold ranking: 6.95
# (flower,bulb) similarity score: 0.491362988948822, gold ranking: 4.48
# ----------------------------
# (flower,violet) similarity score: 0.358908087015152, gold ranking: 6.95
# (flower,endurance) similarity score: 0.384601891040802, gold ranking: 0.4
# ----------------------------
# (guy,stud) similarity score: 0.39128854870796204, gold ranking: 5.83
# (guy,girl) similarity score: 0.7766149640083313, gold ranking: 3.33
# ----------------------------
# (guy,partner) similarity score: 0.2594473361968994, gold ranking: 3.57
# (guy,girl) similarity score: 0.7766149640083313, gold ranking: 3.33
# ----------------------------
# (join,add) similarity score: 0.6252285838127136, gold ranking: 8.1
# (join,marry) similarity score: 0.6763189435005188, gold ranking: 5.35
# ----------------------------
# (king,princess) similarity score: 0.7558279633522034, gold ranking: 3.27
# (king,rook) similarity score: 0.215017631649971, gold ranking: 5.92
# ----------------------------
# (king,rook) similarity score: 0.215017631649971, gold ranking: 5.92
# (king,cabbage) similarity score: 0.24047274887561798, gold ranking: 0.23
# ----------------------------
# (man,uncle) similarity score: 0.30595341324806213, gold ranking: 3.92
# (man,victor) similarity score: 0.3516867756843567, gold ranking: 1.9
# ----------------------------
# (man,uncle) similarity score: 0.30595341324806213, gold ranking: 3.92
# (man,sentry) similarity score: 0.5236843824386597, gold ranking: 3.25
# ----------------------------
# (man,father) similarity score: 0.4272148609161377, gold ranking: 4.83
# (man,child) similarity score: 0.5881257057189941, gold ranking: 4.13
# ----------------------------
# (man,father) similarity score: 0.4272148609161377, gold ranking: 4.83
# (man,sentry) similarity score: 0.5236843824386597, gold ranking: 3.25
# ----------------------------
# (man,father) similarity score: 0.4272148609161377, gold ranking: 4.83
# (man,husband) similarity score: 0.341962605714798, gold ranking: 5.32
# ----------------------------
# (man,father) similarity score: 0.4272148609161377, gold ranking: 4.83
# (man,warrior) similarity score: 0.5930840373039246, gold ranking: 4.72
# ----------------------------
# (man,father) similarity score: 0.4272148609161377, gold ranking: 4.83
# (man,governor) similarity score: 0.31285613775253296, gold ranking: 5.25
# ----------------------------
# (man,child) similarity score: 0.5881257057189941, gold ranking: 4.13
# (man,husband) similarity score: 0.341962605714798, gold ranking: 5.32
# ----------------------------
# (man,child) similarity score: 0.5881257057189941, gold ranking: 4.13
# (man,governor) similarity score: 0.31285613775253296, gold ranking: 5.25
# ----------------------------
# (man,victor) similarity score: 0.3516867756843567, gold ranking: 1.9
# (man,husband) similarity score: 0.341962605714798, gold ranking: 5.32
# ----------------------------
# (man,victor) similarity score: 0.3516867756843567, gold ranking: 1.9
# (man,governor) similarity score: 0.31285613775253296, gold ranking: 5.25
# ----------------------------
# (man,sentry) similarity score: 0.5236843824386597, gold ranking: 3.25
# (man,husband) similarity score: 0.341962605714798, gold ranking: 5.32
# ----------------------------
# (man,sentry) similarity score: 0.5236843824386597, gold ranking: 3.25
# (man,governor) similarity score: 0.31285613775253296, gold ranking: 5.25
# ----------------------------
# (man,husband) similarity score: 0.341962605714798, gold ranking: 5.32
# (man,warrior) similarity score: 0.5930840373039246, gold ranking: 4.72
# ----------------------------
# (man,warrior) similarity score: 0.5930840373039246, gold ranking: 4.72
# (man,governor) similarity score: 0.31285613775253296, gold ranking: 5.25
# ----------------------------
# (meat,bacon) similarity score: 0.2696496248245239, gold ranking: 5.8
# (meat,bread) similarity score: 0.6351309418678284, gold ranking: 1.67
# ----------------------------
# (money,salary) similarity score: 0.4471966624259949, gold ranking: 7.88
# (money,diamond) similarity score: 0.5390303730964661, gold ranking: 3.42
# ----------------------------
# (precedent,information) similarity score: 0.12533746659755707, gold ranking: 3.85
# (precedent,cognition) similarity score: 0.38515740633010864, gold ranking: 2.81
# ----------------------------
# (precedent,information) similarity score: 0.12533746659755707, gold ranking: 3.85
# (precedent,group) similarity score: 0.30249378085136414, gold ranking: 1.77
# ----------------------------
# (situation,condition) similarity score: 0.541646420955658, gold ranking: 6.58
# (situation,conclusion) similarity score: 0.5767530798912048, gold ranking: 4.81
# ----------------------------
# (street,alley) similarity score: 0.6796340942382812, gold ranking: 5.48
# (street,place) similarity score: 0.34163951873779297, gold ranking: 6.44
# ----------------------------
# (street,alley) similarity score: 0.6796340942382812, gold ranking: 5.48
# (street,avenue) similarity score: 0.2498185634613037, gold ranking: 8.88
# ----------------------------
# (street,car) similarity score: 0.5370530486106873, gold ranking: 2.38
# (street,place) similarity score: 0.34163951873779297, gold ranking: 6.44
# ----------------------------
# (street,car) similarity score: 0.5370530486106873, gold ranking: 2.38
# (street,avenue) similarity score: 0.2498185634613037, gold ranking: 8.88
# ----------------------------
# (street,place) similarity score: 0.34163951873779297, gold ranking: 6.44
# (street,avenue) similarity score: 0.2498185634613037, gold ranking: 8.88
# ----------------------------
# (take,obtain) similarity score: 0.5533502697944641, gold ranking: 7.1
# (take,carry) similarity score: 0.6629679799079895, gold ranking: 5.23
# ----------------------------
# (take,obtain) similarity score: 0.5533502697944641, gold ranking: 7.1
# (take,deliver) similarity score: 0.5828465819358826, gold ranking: 4.37
# ----------------------------
# (take,receive) similarity score: 0.5192896127700806, gold ranking: 5.08
# (take,deliver) similarity score: 0.5828465819358826, gold ranking: 4.37
# ----------------------------
# (tiger,feline) similarity score: 0.5217301845550537, gold ranking: 8.0
# (tiger,fauna) similarity score: 0.5467942953109741, gold ranking: 5.62
# ----------------------------
# (tiger,carnivore) similarity score: 0.5, gold ranking: 7.08
# (tiger,fauna) similarity score: 0.5467942953109741, gold ranking: 5.62
# ----------------------------
# (tiger,mammal) similarity score: 0.2930799424648285, gold ranking: 6.85
# (tiger,organism) similarity score: 0.45524880290031433, gold ranking: 4.77
# ----------------------------
# (tiger,mammal) similarity score: 0.2930799424648285, gold ranking: 6.85
# (tiger,fauna) similarity score: 0.5467942953109741, gold ranking: 5.62
# ----------------------------
# (tiger,animal) similarity score: 0.478010892868042, gold ranking: 7.0
# (tiger,fauna) similarity score: 0.5467942953109741, gold ranking: 5.62
# ----------------------------
# (car,horn) similarity score: 0.5853968858718872, gold ranking: 2.57
# (car,highway) similarity score: 0.533865213394165, gold ranking: 3.4
# ----------------------------
# (bad,immoral) similarity score: 0.2574249804019928, gold ranking: 7.62
# (bad,great) similarity score: 0.643903911113739, gold ranking: 0.35
# ----------------------------
# Accuracy: 0.6222222222222222

# %% [markdown]
# ###Results

# %%
get_results("data/Task-1-test-dataset2.csv", "data/10491450-Task1-method-a.csv", ppmi_vector)

# %%
get_results("data/Task-1-test-dataset2.csv", "data/10491450-Task1-method-b.csv", word2vec_vector)
